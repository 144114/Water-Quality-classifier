# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Waterbase_v2018_1_WISE4_csv/Waterbase_v2018_1_T_WISE4_BiologyEQRData.csv")

# %%
data.head()
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0             NL94_OUDMS_A           euMonitoringSiteCode
# 1             NL94_OUDMS_A           euMonitoringSiteCode
# 2             NL94_OUDMS_A           euMonitoringSiteCode
# 3              NO001-51057       eionetMonitoringSiteCode
# 4              NO001-60117       eionetMonitoringSiteCode
#
#   parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 0                         RW                        R8
# 1                         RW                        R8
# 2                         RW                        R8
# 3                         RW                   REL2321
# 4                         RW                   REL2221
#
#   observedPropertyDeterminandBiologyEQRCode  phenomenonTimeReferenceYear  \
# 0                              EEA_123-01-3                         2010
# 1                               EEA_13-01-4                         2007
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29741 entries, 0 to 29740
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   monitoringSiteIdentifier                   29741 non-null  object
#  1   monitoringSiteIdentifierScheme             29741 non-null  object
#  2   parameterWaterBodyCategory                 29741 non-null  object
#  3   parameterNCSWaterBodyType                  29680 non-null  object
#  4   observedPropertyDeterminandBiologyEQRCode  29741 non-null  object
#  5   phenomenonTimeReferenceYear                29741 non-null  int64
#  6   parameterSamplingPeriod                    27503 non-null  object
#  7   resultEcologicalStatusClassValue           29741 non-null  int64
#  8   resultNumberOfSamples                      29741 non-null  int64
#  9   resultEQRValue                             27425 non-null  float64
# ...

# %%
data[["resultEcologicalStatusClassValue","resultNumberOfSamples","resultEQRValue","resultNormalisedEQRValue"]]
# Out:
#        resultEcologicalStatusClassValue  resultNumberOfSamples  \
# 0                                   345                      1
# 1                                   345                      5
# 2                                   345                      5
# 3                                     2                      1
# 4                                     1                      1
# ...                                 ...                    ...
# 29736                                 4                      1
# 29737                               345                      1
# 29738                                 3                      1
# 29739                                 2                      1
# 29740                                 3                      1
#
#        resultEQRValue  resultNormalisedEQRValue
# 0            0.509000                       NaN
# 1            0.518000                       NaN
# 2            0.373000                       NaN
# ...

# %%
data["resultEQRValue"].isna().sum()
# Out:
# 2316

# %%
data = data[data['resultEQRValue'].notna()]

# %%
data.head()
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0             NL94_OUDMS_A           euMonitoringSiteCode
# 1             NL94_OUDMS_A           euMonitoringSiteCode
# 2             NL94_OUDMS_A           euMonitoringSiteCode
# 3              NO001-51057       eionetMonitoringSiteCode
# 4              NO001-60117       eionetMonitoringSiteCode
#
#   parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 0                         RW                        R8
# 1                         RW                        R8
# 2                         RW                        R8
# 3                         RW                   REL2321
# 4                         RW                   REL2221
#
#   observedPropertyDeterminandBiologyEQRCode  phenomenonTimeReferenceYear  \
# 0                              EEA_123-01-3                         2010
# 1                               EEA_13-01-4                         2007
# ...

# %%
data.shape
# Out:
# (27425, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27425 entries, 0 to 29740
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   monitoringSiteIdentifier                   27425 non-null  object
#  1   monitoringSiteIdentifierScheme             27425 non-null  object
#  2   parameterWaterBodyCategory                 27425 non-null  object
#  3   parameterNCSWaterBodyType                  27377 non-null  object
#  4   observedPropertyDeterminandBiologyEQRCode  27425 non-null  object
#  5   phenomenonTimeReferenceYear                27425 non-null  int64
#  6   parameterSamplingPeriod                    26475 non-null  object
#  7   resultEcologicalStatusClassValue           27425 non-null  int64
#  8   resultNumberOfSamples                      27425 non-null  int64
#  9   resultEQRValue                             27425 non-null  float64
# ...

# %%
data.head(10)
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0             NL94_OUDMS_A           euMonitoringSiteCode
# 1             NL94_OUDMS_A           euMonitoringSiteCode
# 2             NL94_OUDMS_A           euMonitoringSiteCode
# 3              NO001-51057       eionetMonitoringSiteCode
# 4              NO001-60117       eionetMonitoringSiteCode
# 5              NO001-60271       eionetMonitoringSiteCode
# 6              NO002-252-L       eionetMonitoringSiteCode
# 7              NO002-27861       eionetMonitoringSiteCode
# 8              NO002-28178       eionetMonitoringSiteCode
# 9              NO002-28730       eionetMonitoringSiteCode
#
#   parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 0                         RW                        R8
# 1                         RW                        R8
# 2                         RW                        R8
# 3                         RW                   REL2321
# ...

# %%
data.value_counts("parameterWaterBodyCategory")[:20]
# Out:
# parameterWaterBodyCategory
# RW    23097
# LW     4309
# TW       12
# CW        7
# dtype: int64

# %%
data["resultEQRValue"].max()
# Out:
# 59.0

# %%
data[data.resultEQRValue >= 2.0][["resultEQRValue","resultNormalisedEQRValue"]]
# Out:
#        resultEQRValue  resultNormalisedEQRValue
# 67               2.02                       NaN
# 69               3.96                       NaN
# 74               2.43                       NaN
# 666              3.00                       NaN
# 667              3.00                       NaN
# ...               ...                       ...
# 29498            2.10                       NaN
# 29567            4.59                       NaN
# 29590            2.38                       NaN
# 29665            4.18                       NaN
# 29708            3.25                       NaN
#
# [182 rows x 2 columns]

# %%
data[(data.resultNormalisedEQRValue == 1.0)][["resultEQRValue","resultNormalisedEQRValue"]].describe()
# Out:
#        resultEQRValue  resultNormalisedEQRValue
# count     3749.000000                    3773.0
# mean         0.936223                       1.0
# std          0.270939                       0.0
# min          0.000000                       1.0
# 25%          1.000000                       1.0
# 50%          1.000000                       1.0
# 75%          1.071429                       1.0
# max          2.000000                       1.0

# %%
data[data.resultNormalisedEQRValue == 1.0][["resultEQRValue","resultNormalisedEQRValue"]].describe()

# %%
data[]

# %%
data.describe()
# Out:
#        phenomenonTimeReferenceYear  resultEcologicalStatusClassValue  \
# count                 29741.000000                      29741.000000
# mean                   2012.130426                         13.336875
# std                       2.432112                         61.069266
# min                    1992.000000                          1.000000
# 25%                    2010.000000                          1.000000
# 50%                    2012.000000                          2.000000
# 75%                    2014.000000                          3.000000
# max                    2017.000000                        345.000000
#
#        resultNumberOfSamples  resultEQRValue  resultNormalisedEQRValue  \
# count           29741.000000    27425.000000              19714.000000
# mean                1.791903        0.805671                  0.707798
# std                 1.418429        1.665382                  0.222220
# ...

# %%
data[data.resultNormalisedEQRValue == 1.0]["resultEQRValue"].max()
# Out:
# 2.0

# %%
data = data[data.resultEQRValue != 59.0]

# %%
data = data[data.resultEQRValue != 57.0]

# %%
data = data[data.resultEQRValue != 51.0]

# %%
data.describe()
# Out:
#        phenomenonTimeReferenceYear  resultEcologicalStatusClassValue  \
# count                 27421.000000                      27421.000000
# mean                   2012.050800                         14.010795
# std                       2.466421                         62.780417
# min                    1992.000000                          1.000000
# 25%                    2010.000000                          1.000000
# 50%                    2012.000000                          2.000000
# 75%                    2014.000000                          3.000000
# max                    2017.000000                        345.000000
#
#        resultNumberOfSamples  resultEQRValue  resultNormalisedEQRValue  \
# count           27421.000000    27421.000000              18848.000000
# mean                1.754896        0.797547                  0.707950
# std                 1.410982        1.523080                  0.223777
# ...

# %%
data[data.resultNormalisedEQRValue < 0]
# Out:
#       monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 28874             ITR110041AAR           euMonitoringSiteCode
# 28907             ITR1101406AS           euMonitoringSiteCode
#
#       parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 28874                         RW                     M1
# 28907                         RW                     M1
#
#       observedPropertyDeterminandBiologyEQRCode  phenomenonTimeReferenceYear  \
# 28874                               EEA_13-01-4                         2012
# 28907                               EEA_13-01-4                         2012
#
#       parameterSamplingPeriod  resultEcologicalStatusClassValue  \
# 28874        2012-01--2012-12                                 4
# 28907        2012-01--2012-12                                 4
#
#        resultNumberOfSamples  resultEQRValue  resultNormalisedEQRValue  \
# 28874                      2           0.207                 -0.027500
# ...

# %%
data = data[data.resultEQRValue <= 2.0]

# %%
data[data.resultEQRValue >= 1.3]
# Out:
#       monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 29         PLSM_PL07S0802_0057           euMonitoringSiteCode
# 58         PLSM_PL01S0202_2272           euMonitoringSiteCode
# 64          ES020ESPF004300399           euMonitoringSiteCode
# 66         PLSM_PL01S0602_0354           euMonitoringSiteCode
# 490               FRDR06970900           euMonitoringSiteCode
# ...                        ...                            ...
# 29131           PL01S0602_3011           euMonitoringSiteCode
# 29140           PL01S1102_0648           euMonitoringSiteCode
# 29163           PL01S0702_0538           euMonitoringSiteCode
# 29418           PL01S0602_3030           euMonitoringSiteCode
# 29419           PL02S0502_0182           euMonitoringSiteCode
#
#       parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 29                            LW                        5a
# 58                            LW                        3a
# ...

# %%
data.resultNormalisedEQRValue.max()
# Out:
# 1.0

# %%
data[data.resultNormalisedEQRValue == 1.0]["resultEQRValue"].max()
# Out:
# 2.0

# %%
data[data.resultNormalisedEQRValue == 1.0]
# Out:
#       monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 6                  NO002-252-L       eionetMonitoringSiteCode
# 15                 NO002-57223       eionetMonitoringSiteCode
# 40                 NO002-58998       eionetMonitoringSiteCode
# 104               LUL112010A11           euMonitoringSiteCode
# 183                      UK293       eionetMonitoringSiteCode
# ...                        ...                            ...
# 29684          SE728095-175926           euMonitoringSiteCode
# 29686          SE728095-175926           euMonitoringSiteCode
# 29687          SE728095-175926           euMonitoringSiteCode
# 29689          SE728095-175926           euMonitoringSiteCode
# 29722           PL01S1501_1755           euMonitoringSiteCode
#
#       parameterWaterBodyCategory  \
# 6                             LW
# 15                            RW
# 40                            RW
# 104                           RW
# 183                           RW
# ...

# %%
data[data.resultNormalisedEQRValue == 1.0]["resultEQRValue"]
# Out:
# 6        1.03719
# 15       1.08000
# 40       1.10000
# 104      1.05900
# 183      1.12000
#           ...
# 29684    1.00000
# 29686    1.00000
# 29687    1.04100
# 29689    1.00000
# 29722    1.00000
# Name: resultEQRValue, Length: 3749, dtype: float64

# %%
data.describe()
# Out:
#        phenomenonTimeReferenceYear  resultEcologicalStatusClassValue  \
# count                 27245.000000                      27245.000000
# mean                   2012.051239                         13.945898
# std                       2.470338                         62.624416
# min                    1992.000000                          1.000000
# 25%                    2010.000000                          1.000000
# 50%                    2012.000000                          2.000000
# 75%                    2014.000000                          3.000000
# max                    2017.000000                        345.000000
#
#        resultNumberOfSamples  resultEQRValue  resultNormalisedEQRValue  \
# count           27245.000000    27245.000000              18848.000000
# mean                1.753129        0.721350                  0.707950
# std                 1.410621        0.245548                  0.223777
# ...

# %%
data = data[data.resultNormalisedEQRValue >= 0]

# %%
data.describe()
# Out:
#        phenomenonTimeReferenceYear  resultEcologicalStatusClassValue  \
# count                 18846.000000                      18846.000000
# mean                   2011.574605                          8.816194
# std                       2.368949                         47.586054
# min                    1992.000000                          1.000000
# 25%                    2010.000000                          1.000000
# 50%                    2011.000000                          2.000000
# 75%                    2013.000000                          3.000000
# max                    2017.000000                        345.000000
#
#        resultNumberOfSamples  resultEQRValue  resultNormalisedEQRValue  \
# count           18846.000000    18846.000000              18846.000000
# mean                1.741537        0.742750                  0.708029
# std                 1.403253        0.242068                  0.223656
# ...

# %%
data.value_counts("resultEcologicalStatusClassValue")
# Out:
# resultEcologicalStatusClassValue
# 2      6557
# 1      6198
# 3      4047
# 4      1323
# 345     370
# 5       351
# dtype: int64

# %%
data.to_csv('EQR_clean.csv')
