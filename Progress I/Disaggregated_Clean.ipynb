# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Waterbase_v2018_1_WISE4_csv/Waterbase_v2018_1_T_WISE4_DisaggregatedData.csv")
# Out:
# C:\Users\teera\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11,13,14,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0               IT01044005           euMonitoringSiteCode
# 1               IT01044005           euMonitoringSiteCode
# 2               IT01044005           euMonitoringSiteCode
# 3               IT01044005           euMonitoringSiteCode
# 4               IT01044005           euMonitoringSiteCode
#
#   parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                         RW                   CAS_7440-38-2
# 1                         RW                   CAS_7439-89-6
# 2                         RW                   CAS_7440-66-6
# 3                         RW                   CAS_7440-66-6
# 4                         RW                   CAS_7440-02-0
#
#   procedureAnalysedFraction procedureAnalysedMedia resultUom  \
# 0                     total                  water      ug/L
# 1                     total                  water      ug/L
# ...

# %%
data.shape
# Out:
# (33848578, 21)

# %%
data.metadata_observationStatus.value_counts()
# Out:
# A    33051438
# U      797140
# Name: metadata_observationStatus, dtype: int64

# %%
data = data[data["metadata_observationStatus"] != "U"]

# %%
data["resultObservationStatus"].value_counts()
# Out:
# A    2450235
# O      12341
# N       2967
# Y        915
# L         95
# Name: resultObservationStatus, dtype: int64

# %%
data = data[data["resultObservationStatus"] != "O"]

# %%
data = data[data["resultObservationStatus"] != "N"]

# %%
data = data[data["resultObservationStatus"] != "Y"]

# %%
data = data[data["resultObservationStatus"] != "L"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33035120 entries, 0 to 33848577
# Data columns (total 21 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   monitoringSiteIdentifier            object
#  1   monitoringSiteIdentifierScheme      object
#  2   parameterWaterBodyCategory          object
#  3   observedPropertyDeterminandCode     object
#  4   procedureAnalysedFraction           object
#  5   procedureAnalysedMedia              object
#  6   resultUom                           object
#  7   phenomenonTimeSamplingDate          object
#  8   resultObservedValue                 float64
#  9   resultQualityObservedValueBelowLOQ  int64
#  10  procedureLOQValue                   float64
#  11  procedureAnalyticalMethod           object
#  12  parameterSampleDepth                float64
#  13  resultObservationStatus             object
#  14  Remarks                             object
# ...

# %%
data["parameterWaterBodyCategory"].value_counts()
# Out:
# RW    17458364
# GW    13840567
# LW     1679460
# TW       55532
# CW        1197
# Name: parameterWaterBodyCategory, dtype: int64

# %%
data.head()
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0               IT01044005           euMonitoringSiteCode
# 1               IT01044005           euMonitoringSiteCode
# 2               IT01044005           euMonitoringSiteCode
# 3               IT01044005           euMonitoringSiteCode
# 4               IT01044005           euMonitoringSiteCode
#
#   parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                         RW                   CAS_7440-38-2
# 1                         RW                   CAS_7439-89-6
# 2                         RW                   CAS_7440-66-6
# 3                         RW                   CAS_7440-66-6
# 4                         RW                   CAS_7440-02-0
#
#   procedureAnalysedFraction procedureAnalysedMedia resultUom  \
# 0                     total                  water      ug/L
# 1                     total                  water      ug/L
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33035120 entries, 0 to 33848577
# Data columns (total 21 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   monitoringSiteIdentifier            object
#  1   monitoringSiteIdentifierScheme      object
#  2   parameterWaterBodyCategory          object
#  3   observedPropertyDeterminandCode     object
#  4   procedureAnalysedFraction           object
#  5   procedureAnalysedMedia              object
#  6   resultUom                           object
#  7   phenomenonTimeSamplingDate          object
#  8   resultObservedValue                 float64
#  9   resultQualityObservedValueBelowLOQ  int64
#  10  procedureLOQValue                   float64
#  11  procedureAnalyticalMethod           object
#  12  parameterSampleDepth                float64
#  13  resultObservationStatus             object
#  14  Remarks                             object
# ...

# %%
data.shape
# Out:
# (33035120, 21)

# %%
data.drop(data.columns[14:17], axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33035120 entries, 0 to 33848577
# Data columns (total 18 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   monitoringSiteIdentifier            object
#  1   monitoringSiteIdentifierScheme      object
#  2   parameterWaterBodyCategory          object
#  3   observedPropertyDeterminandCode     object
#  4   procedureAnalysedFraction           object
#  5   procedureAnalysedMedia              object
#  6   resultUom                           object
#  7   phenomenonTimeSamplingDate          object
#  8   resultObservedValue                 float64
#  9   resultQualityObservedValueBelowLOQ  int64
#  10  procedureLOQValue                   float64
#  11  procedureAnalyticalMethod           object
#  12  parameterSampleDepth                float64
#  13  resultObservationStatus             object
#  14  metadata_statusCode                 object
# ...

# %%
data.head()
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0               IT01044005           euMonitoringSiteCode
# 1               IT01044005           euMonitoringSiteCode
# 2               IT01044005           euMonitoringSiteCode
# 3               IT01044005           euMonitoringSiteCode
# 4               IT01044005           euMonitoringSiteCode
#
#   parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                         RW                   CAS_7440-38-2
# 1                         RW                   CAS_7439-89-6
# 2                         RW                   CAS_7440-66-6
# 3                         RW                   CAS_7440-66-6
# 4                         RW                   CAS_7440-02-0
#
#   procedureAnalysedFraction procedureAnalysedMedia resultUom  \
# 0                     total                  water      ug/L
# 1                     total                  water      ug/L
# ...

# %%
data.to_csv('Disaggregated_clean.csv')

# %%
data.drop(data.columns[3:7], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-40-c2826ae40f5e> in <module>
# ----> 1 data.drop(data.columns[3:7], axis=1,inplace=True)
#
# c:\Users\teera\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\Users\teera\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
data.drop(data.columns[16], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-35-6cc149b5956c> in <module>
# ----> 1 data.drop(data.columns[16], axis=1,inplace=True)
#
# c:\Users\teera\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\Users\teera\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...
