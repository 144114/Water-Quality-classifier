# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Waterbase_v2018_1_WISE4_csv/Waterbase_v2018_1_T_WISE4_BiologyEQRClassificationProcedure.csv")

# %%
data.head()
# Out:
#   CountryCode observedPropertyDeterminandBiologyEQRCode  \
# 0          AT                               EEA_11-04-1
# 1          AT                               EEA_11-04-1
# 2          AT                               EEA_11-04-1
# 3          AT                               EEA_11-04-1
# 4          AT                               EEA_11-04-1
#
#   parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 0                         LW                        B1
# 1                         LW                        B2
# 2                         LW                       C1a
# 3                         LW                       C1b
# 4                         LW                        D1
#
#   parameterWFDIntercalibrationWaterBodyType parameterNaturalAWBHMWB  \
# 0                                       NaN                 Natural
# 1                                       NaN                 Natural
# 2                                       NaN                 Natural
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2553 entries, 0 to 2552
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   CountryCode                                     2553 non-null   object
#  1   observedPropertyDeterminandBiologyEQRCode       2553 non-null   object
#  2   parameterWaterBodyCategory                      2553 non-null   object
#  3   parameterNCSWaterBodyType                       2553 non-null   object
#  4   parameterWFDIntercalibrationWaterBodyType       925 non-null    object
#  5   parameterNaturalAWBHMWB                         2506 non-null   object
#  6   parameterICStatusOfDeterminandBiologyEQR        2553 non-null   int64
#  7   parameterBoundaryValueClasses12                 2215 non-null   float64
#  8   parameterBoundaryValueClasses23                 2419 non-null   float64
# ...

# %%
data["parameterICStatusOfDeterminandBiologyEQR"].value_counts()
# Out:
# 0    1360
# 1    1193
# Name: parameterICStatusOfDeterminandBiologyEQR, dtype: int64

# %%
data[["CountryCode","parameterBoundaryValueClasses12","parameterBoundaryValueClasses23","parameterBoundaryValueClasses34","parameterBoundaryValueClasses45"]].groupby("CountryCode").mean()
# Out:
#              parameterBoundaryValueClasses12  parameterBoundaryValueClasses23  \
# CountryCode
# AT                                  0.813250                         0.600750
# BE                                  0.964214                         0.702354
# BG                                  0.810273                         0.622341
# CH                                       NaN                              NaN
# CY                                  0.963000                         0.714067
# DE                                  0.765000                         0.575000
# EE                                  0.783125                         0.570625
# ES                                  0.863333                         0.649048
# FI                                  0.800000                         0.600000
# FR                                  0.935577                         0.788305
# GB                                  0.900453                         0.754115
# ...

# %%
data[data["CountryCode"] == "CH"]
# Out:
#      CountryCode observedPropertyDeterminandBiologyEQRCode  \
# 1223          CH                              EEA_124-01-6
# 1224          CH                               EEA_13-01-4
#
#      parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 1223                         RW                   general
# 1224                         RW                   general
#
#      parameterWFDIntercalibrationWaterBodyType parameterNaturalAWBHMWB  \
# 1223                                       NaN                 Natural
# 1224                                       NaN                 Natural
#
#       parameterICStatusOfDeterminandBiologyEQR  \
# 1223                                         0
# 1224                                         0
#
#       parameterBoundaryValueClasses12  parameterBoundaryValueClasses23  \
# 1223                              NaN                              NaN
# 1224                              NaN                              NaN
#
# ...

# %%
data = data[data["CountryCode"] != "CH"]

# %%
data = data[["CountryCode","parameterBoundaryValueClasses12","parameterBoundaryValueClasses23","parameterBoundaryValueClasses34","parameterBoundaryValueClasses45"]].groupby("CountryCode").mean()

# %%
data.to_csv("EQR_Citeria.csv")

# %%
data = pd.read_csv("EQR_Citeria.csv")

# %%
data
# Out:
#    CountryCode  parameterBoundaryValueClasses12  \
# 0           AT                         0.813250
# 1           BE                         0.964214
# 2           BG                         0.810273
# 3           CY                         0.963000
# 4           DE                         0.765000
# 5           EE                         0.783125
# 6           ES                         0.863333
# 7           FI                         0.800000
# 8           FR                         0.935577
# 9           GB                         0.900453
# 10          HR                         0.802679
# 11          IE                         0.841844
# 12          IT                         0.906701
# 13          LT                         0.711724
# 14          LU                         0.972800
# 15          LV                         0.864444
# 16          NL                         0.800000
# 17          NO                         0.961429
# ...
